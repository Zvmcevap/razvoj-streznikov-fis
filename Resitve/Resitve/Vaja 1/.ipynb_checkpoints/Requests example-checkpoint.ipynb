# %%
# curl -X 'POST' 'http://127.0.0.1:1234/posttext' -H 'Content-Type: text/html'  -d 'ASD'

# curl -X 'POST' 'http://127.0.0.1:1234/postjson' -H 'Content-Type: application/json' \
#   -d '{
#   "mytext":"Proba"
#   }'

# %%
import requests
import json

# %%
res = requests.get('http://149.62.71.186:1234/welcome')

# %%
res.text
# Out:
# '<h1>Welcome!</h1>'

# %%
res = requests.post('http://149.62.71.186:1234/posttext', data = 'SADASDAS')
res.text
# Out:
# 'Hvala za text. Je dolžine 8.'

# %%
res = requests.post('http://149.62.71.186:1234/postjson', json={'name': 'Martin', 'surname' : 'Brešar'})
res.text
# Out:
# 'Hvala za JSON. Ima 2 vrednosti.'
