# %%
# curl -X 'PUT' 'http://127.0.0.1:1234/puttext' -H 'Content-Type: text/html'  -d 'ASD'

# curl -X 'PUT' 'http://127.0.0.1:1234/putjson' -H 'Content-Type: application/json' \
#   -d '{
#   "mytext":"Proba"
#   }'

# %%
import requests
import json

# %%
res = requests.get('http://127.0.0.1:1234/welcome')

# %%
res.text
# Out:
# '<h1>Welcome!</h1>'

# %%
res = requests.put('http://127.0.0.1:1234/puttext', data = 'ASD')
res.text
# Out:
# 'Hvala za text. Je dolžine 3.'

# %%
res = requests.put('http://127.0.0.1:1234/putjson', json={'name': 'Martin'})
res.text
# Out:
# 'Hvala za JSON. Ima 1 vrednosti.'
