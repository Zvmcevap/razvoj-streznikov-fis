# %%
import pika
import sys

credentials = pika.PlainCredentials('martin', 'martin00')
parameters =  pika.ConnectionParameters('149.62.71.186', credentials=credentials)
connection = pika.BlockingConnection(parameters)
channel = connection.channel()

channel.exchange_declare(exchange='direct_logs', exchange_type='direct')

result = channel.queue_declare(queue='', exclusive=True)
queue_name = result.method.queue

# %%
channel.queue_bind(exchange='direct_logs', queue=queue_name, routing_key='info')
channel.queue_bind(exchange='direct_logs', queue=queue_name, routing_key='warning')
channel.queue_bind(exchange='direct_logs', queue=queue_name, routing_key='error')
# Out:
# <METHOD(['channel_number=1', 'frame_type=1', 'method=<Queue.BindOk>'])>

# %%
print('Waiting for logs. To exit press CTRL+C')


def callback(ch, method, properties, body):
    print("Received %r:%r" % (method.routing_key, body.decode()))


channel.basic_consume(
    queue=queue_name, on_message_callback=callback, auto_ack=True)
# Out:
# Waiting for logs. To exit press CTRL+C
# 'ctag1.3e4c5ef6bdcf49c29178c3a0c771ec14'

# %%
channel.start_consuming()
# Out:
# Received 'warning':'2023-03-22 14:28:25.692505'
# Received 'info':'2023-03-22 14:28:28.711820'
# Received 'info':'2023-03-22 14:28:29.717882'
# Received 'info':'2023-03-22 14:28:30.720324'
# Received 'warning':'2023-03-22 14:28:31.722889'
# Received 'info':'2023-03-22 14:28:32.724141'
# Received 'warning':'2023-03-22 14:28:33.732580'
# Received 'error':'2023-03-22 14:28:34.735059'
# Received 'info':'2023-03-22 14:28:35.736851'
# Received 'error':'2023-03-22 14:28:37.745317'
# Received 'warning':'2023-03-22 14:28:38.749279'
# Received 'error':'2023-03-22 14:28:39.757163'
# Received 'error':'2023-03-22 14:28:42.765316'
# Received 'info':'2023-03-22 14:28:43.767103'
# Received 'error':'2023-03-22 14:28:44.770064'
# Received 'warning':'2023-03-22 14:28:46.779138'
# Received 'error':'2023-03-22 14:28:47.780778'
# Received 'info':'2023-03-22 14:28:48.785176'
# Received 'warning':'2023-03-22 14:28:49.787755'
# Received 'warning':'2023-03-22 14:28:50.789340'
# Received 'error':'2023-03-22 14:28:51.792162'
# Received 'info':'2023-03-22 14:28:52.795450'
# Received 'warning':'2023-03-22 14:28:53.799487'
# Received 'error':'2023-03-22 14:28:55.806647'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b83aef2ca6ee> in <module>
# ----> 1 channel.start_consuming()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pika/adapters/blocking_connection.py in start_consuming(self)
#    1863         while self._consumer_infos:
#    1864             # This will raise ChannelClosed if channel is closed by broker
# -> 1865             self._process_data_events(time_limit=None)
#    1866
#    1867     def stop_consuming(self, consumer_tag=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pika/adapters/blocking_connection.py in _process_data_events(self, time_limit)
#    2024
#    2025         """
# -> 2026         self.connection.process_data_events(time_limit=time_limit)
#    2027         if self.is_closed and isinstance(self._closing_reason,
#    2028                                          exceptions.ChannelClosedByBroker):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pika/adapters/blocking_connection.py in process_data_events(self, time_limit)
#     822                                               self._ready_events))
#     823             if time_limit is None:
# --> 824                 self._flush_output(common_terminator)
#     825             else:
#     826                 with _IoloopTimerContext(time_limit, self._impl) as timer:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pika/adapters/blocking_connection.py in _flush_output(self, *waiters)
#     512         # Process I/O until our completion condition is satisfied
#     513         while not is_done():
# --> 514             self._impl.ioloop.poll()
#     515             self._impl.ioloop.process_timeouts()
#     516
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pika/adapters/select_connection.py in poll(self)
#     577
#     578         """
# --> 579         self._poller.poll()
#     580
#     581
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pika/adapters/select_connection.py in poll(self)
#    1062         while True:
#    1063             try:
# -> 1064                 kevents = self._kqueue.control(None, 1000, self._get_max_wait())
#    1065                 break
#    1066             except _SELECT_ERRORS as error:
#
# KeyboardInterrupt:
